# %% [markdown]
# ## Application of Dalex
# #### Dalex is available at https://github.com/ModelOriented/DALEX

# %%
import dalex as dx
import pandas as pd
import numpy as np
import sklearn
import pickle

# %% [markdown]
# #### Retrieve train and test set, train the model

# %%
nome = 'adult'
title = "../datasets/train_set_"+nome+"_strat.p"
train = open(title,"rb")
train_set = pickle.load(train)
title = "../datasets/train_label_"+nome+"_strat.p"
train_l = open(title,"rb")
train_label = pickle.load(train_l)
title = "../datasets/test_set_" + nome + "_strat.p"
test = open(title, "rb")
test_set = pickle.load(test)
title = "../datasets/test_label_" + nome + "_strat.p"
test_l = open(title, "rb")
test_label = pickle.load(test_l)
train_set = train_set.apply(pd.to_numeric)
test_set = test_set.apply(pd.to_numeric)

# %%
train_set.describe()
# Out:
#                 age     workclass        fnlwgt  education-num  \
# count  21113.000000  21113.000000  2.111300e+04   21113.000000
# mean      38.406243      2.110122  1.901805e+05      10.113863
# std       13.135741      0.936780  1.050692e+05       2.543448
# min       17.000000      0.000000  1.487800e+04       1.000000
# 25%       28.000000      2.000000  1.177890e+05       9.000000
# 50%       37.000000      2.000000  1.791710e+05      10.000000
# 75%       47.000000      2.000000  2.383970e+05      12.000000
# max       90.000000      6.000000  1.455435e+06      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    21113.000000  21113.000000  21113.000000  21113.000000  21113.000000
# mean         3.326481      6.357126      2.773504      1.209444      0.321982
# std          2.706099      4.129759      1.675771      0.607902      0.467247
# min          1.000000      1.000000      1.000000      1.000000      0.000000
# 25%          1.000000      3.000000      1.000000      1.000000      0.000000
# 50%          2.000000      5.000000      3.000000      1.000000      0.000000
# 75%          7.000000     10.000000      5.000000      1.000000      1.000000
# max          7.000000     14.000000      5.000000      5.000000      1.000000
#
#        capital-gain  capital-loss  hours-per-week  native-country
# count  21113.000000  21113.000000    21113.000000    21113.000000
# mean    1099.897504     88.369962       40.918392       38.611851
# std     7426.180557    404.943602       11.973490        8.362540
# min        0.000000      0.000000        1.000000        1.000000
# 25%        0.000000      0.000000       40.000000       41.000000
# 50%        0.000000      0.000000       40.000000       41.000000
# 75%        0.000000      0.000000       45.000000       41.000000
# max    99999.000000   4356.000000       99.000000       41.000000

# %%
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
bb = XGBClassifier(C= 1, penalty='l2', objective='binary:logistic', seed = 42, bootstrap=True, max_depth=90,learning_rate=0.1, n_estimators=500, tree_method='auto')
bb.fit(train_set.values, train_label.values)
# Out:
# /Users/narets/opt/anaconda3/envs/generic_latest/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:56:45] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:541:
# Parameters: { C, bootstrap, penalty } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [09:56:45] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(C=1, base_score=0.5, booster='gbtree', bootstrap=True,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=90, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=500, n_jobs=12,
#               num_parallel_tree=1, penalty='l2', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=42, subsample=1,
#               tree_method='auto', validate_parameters=1, verbosity=None)

# %%
bb.predict(test_set.iloc[58].values.reshape(1, -1))
# Out:
# array([1])

# %% [markdown]
# ### Create the explainer
# #### We have to pass the black box model, the train set and the train label

# %%
import time
start = time.time()
exp = dx.Explainer(bb, train_set, train_label)
end = time.time()
print('Time for creation ', end - start)
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 21113 rows 13 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 21113 values
#   -> model_class       : xgboost.sklearn.XGBClassifier (default)
#   -> label             : Not specified, model's class short name will be used. (default)
#   -> predict function  : <function yhat_proba_default at 0x1198d1dd0> will be used (default)
#   -> predict function  : Accepts pandas.DataFrame and numpy.ndarray.
#   -> predicted values  : min = 1.02e-06, mean = 0.25, max = 1.0
#   -> model type        : classification will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -0.504, mean = -2.94e-06, max = 0.496
#   -> model_info        : package xgboost
#
# A new explainer has been created!
# Time for creation  0.23270106315612793

# %% [markdown]
# ### Dalex allows for different kinds of feature importance based explanations. Here we report the shap explanation of a record

# %%
#the record we are going to explain 
test_set.iloc[58, :]
# Out:
# age                   40
# workclass              2
# fnlwgt            144995
# education-num         11
# marital-status         1
# occupation             9
# relationship           1
# race                   1
# sex                    0
# capital-gain        4386
# capital-loss           0
# hours-per-week        40
# native-country        41
# Name: 713, dtype: int64

# %%
bb.predict(test_set.iloc[58, :].values.reshape(1, -1))
# Out:
# array([1])

# %%
exp.predict_parts(test_set.iloc[58, :], type='shap').plot()
# Out:
# <div>                            <div id="973af42b-8fb8-4280-822b-0010faa707f8" class="plotly-graph-div" style="height:373.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("973af42b-8fb8-4280-822b-0010faa707f8")) {                    Plotly.newPlot(                        "973af42b-8fb8-4280-822b-0010faa707f8",                        [{"base": 0.25041741132736206, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 0.25<br>Prediction: 0.779<br>capital-gain = 4386.0<br>increases average response <br>by 0.207", "Average response: 0.25<br>Prediction: 0.779<br>relationship = 1.0<br>increases average response <br>by 0.183", "Average response: 0.25<br>Prediction: 0.779<br>fnlwgt = 145000.0<br>decreases average response <br>by 0.115", "Average response: 0.25<br>Prediction: 0.779<br>marital-status = 1.0<br>increases average response <br>by 0.078", "Average response: 0.25<br>Prediction: 0.779<br>age = 40.0<br>increases average response <br>by 0.058", "Average response: 0.25<br>Prediction: 0.779<br>occupation = 9.0<br>increases average response <br>by 0.05", "Average response: 0.25<br>Prediction: 0.779<br>education-num = 11.0<br>increases average response <br>by 0.027", "Average response: 0.25<br>Prediction: 0.779<br>hours-per-week = 40.0<br>increases average response <br>by 0.022", "Average response: 0.25<br>Prediction: 0.779<br>race = 1.0<br>increases average response <br>by 0.011", "Average response: 0.25<br>Prediction: 0.779<br>+ all other factors<br>increases average response <br>by 0.008"], "marker": {"color": ["#8bdcbe", "#8bdcbe", "#f05a71", "#8bdcbe", "#8bdcbe", "#8bdcbe", "#8bdcbe", "#8bdcbe", "#8bdcbe", "#8bdcbe"]}, "orientation": "h", "showlegend": false, "text": ["+0.207", "+0.183", "-0.115", "+0.078", "+0.058", "+0.05", "+0.027", "+0.022", "+0.011", "+0.008"], "textposition": "outside", "type": "bar", "x": [0.207, 0.183, -0.115, 0.078, 0.058, 0.05, 0.027, 0.022, 0.011, 0.008], "xaxis": "x", "y": ["capital-gain = 4386.0", "relationship = 1.0", "fnlwgt = 145000.0", "marital-status = 1.0", "age = 40.0", "occupation = 9.0", "education-num = 11.0", "hours-per-week = 40.0", "race = 1.0", "+ all other factors"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 373.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.25041741132736206, "x1": 0.25041741132736206, "xref": "x", "y0": -1, "y1": 11, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Shapley Values", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [0.08711741132736209, 0.505717411327362], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ...
#
# var gd = document.getElementById('973af42b-8fb8-4280-822b-0010faa707f8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# #### Another plot available from Dalex is the ceteris paribus.

# %%
test_set.iloc[4, :]
# Out:
# age                   38
# workclass              2
# fnlwgt            260997
# education-num         10
# marital-status         1
# occupation             8
# relationship           1
# race                   2
# sex                    0
# capital-gain           0
# capital-loss           0
# hours-per-week        40
# native-country        41
# Name: 19683, dtype: int64

# %%
ceteris_paribus_ex = exp.predict_profile(test_set.iloc[4, :])
ceteris_paribus_ex.result
# Out:
# Calculating ceteris paribus: 100%|██████████| 13/13 [00:00<00:00, 112.17it/s]
#          age  workclass    fnlwgt  education-num  marital-status  occupation  \
# 19683  17.00        2.0  260997.0           10.0             1.0         8.0
# 19683  17.73        2.0  260997.0           10.0             1.0         8.0
# 19683  18.46        2.0  260997.0           10.0             1.0         8.0
# 19683  19.19        2.0  260997.0           10.0             1.0         8.0
# 19683  19.92        2.0  260997.0           10.0             1.0         8.0
# ...      ...        ...       ...            ...             ...         ...
# 19683  38.00        2.0  260997.0           10.0             1.0         8.0
# 19683  38.00        2.0  260997.0           10.0             1.0         8.0
# 19683  38.00        2.0  260997.0           10.0             1.0         8.0
# 19683  38.00        2.0  260997.0           10.0             1.0         8.0
# 19683  38.00        2.0  260997.0           10.0             1.0         8.0
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# ...             ...   ...  ...           ...           ...             ...
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
# 19683           1.0   2.0  0.0           0.0           0.0            40.0
#
#        native-country  _original_    _yhat_         _vname_  _ids_  \
# 19683            41.0          38  0.000309             age  19683
# 19683            41.0          38  0.000309             age  19683
# 19683            41.0          38  0.000309             age  19683
# 19683            41.0          38  0.000309             age  19683
# 19683            41.0          38  0.000309             age  19683
# ...               ...         ...       ...             ...    ...
# 19683            39.4          41  0.006204  native-country  19683
# 19683            39.8          41  0.006271  native-country  19683
# 19683            40.2          41  0.005429  native-country  19683
# 19683            40.6          41  0.005429  native-country  19683
# 19683            41.0          41  0.005429  native-country  19683
#
#              _label_
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
# ...              ...
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
# 19683  XGBClassifier
#
# [1318 rows x 18 columns]

# %%
ceteris_paribus_ex.plot(variables = ['capital-gain', 'capital-loss'])
# Out:
# <div>                            <div id="68674aba-96c6-4dc8-9127-db6b3867fb98" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68674aba-96c6-4dc8-9127-db6b3867fb98")) {                    Plotly.newPlot(                        "68674aba-96c6-4dc8-9127-db6b3867fb98",                        [{"customdata": [["</br>id: 19683</br>prediction: 0.005</br>capital-gain: 0.0</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.0</br>capital-gain: 999.99</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.0</br>capital-gain: 1999.98</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.128</br>capital-gain: 2999.9700000000003</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.001</br>capital-gain: 3999.96</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.004</br>capital-gain: 4999.95</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.998</br>capital-gain: 5999.9400000000005</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.998</br>capital-gain: 6999.93</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 1.0</br>capital-gain: 7999.92</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-loss: 0.0</br>hours-per-week: 40.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 1.0</br>capital-gain: 8999.91</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>o ...

# %% [markdown]
# #### We can visualize more records at the same time

# %%
ceteris_58 = exp.predict_profile(test_set.iloc[58, :])
ceteris_paribus_ex.plot(ceteris_58, variables = ['hours-per-week', 'capital-gain'])
# Out:
# Calculating ceteris paribus: 100%|██████████| 13/13 [00:00<00:00, 154.60it/s]
# <div>                            <div id="654ae77d-7683-417b-9232-1993c9f6eaa5" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("654ae77d-7683-417b-9232-1993c9f6eaa5")) {                    Plotly.newPlot(                        "654ae77d-7683-417b-9232-1993c9f6eaa5",                        [{"customdata": [["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 1.0</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 1.98</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 2.96</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 3.94</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 4.92</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.024</br>hours-per-week: 5.9</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.018</br>hours-per-week: 6.88</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.011</br>hours-per-week: 7.859999999999999</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.011</br>hours-per-week: 8.84</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1.0</br>race: 2.0</br>sex: 0.0</br>capital-gain: 0.0</br>capital-loss: 0.0</br>native-country: 41.0</br>_original_yhat_: 0.005429017823189497</br>"], ["</br>id: 19683</br>prediction: 0.009</br>hours-per-week: 9.82</br></br>age: 38.0</br>workclass: 2.0</br>fnlwgt: 260997.0</br>education-num: 10.0</br>marital-status: 1.0</br>occupation: 8.0</br>relationship: 1. ...

# %% [markdown]
# #### Another interesting plot is the break down plot

# %%
import matplotlib
from matplotlib.pyplot import figure
exp.predict_parts(test_set.iloc[2, :], type='shap').plot(min_max=[0,1])
# Out:
# <div>                            <div id="b62263cf-fcec-4fa9-8e13-cdfb8db570b3" class="plotly-graph-div" style="height:373.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b62263cf-fcec-4fa9-8e13-cdfb8db570b3")) {                    Plotly.newPlot(                        "b62263cf-fcec-4fa9-8e13-cdfb8db570b3",                        [{"base": 0.25041741132736206, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 0.25<br>Prediction: 0.232<br>relationship = 4.0<br>decreases average response <br>by 0.068", "Average response: 0.25<br>Prediction: 0.232<br>occupation = 1.0<br>increases average response <br>by 0.054", "Average response: 0.25<br>Prediction: 0.232<br>capital-gain = 0.0<br>decreases average response <br>by 0.033", "Average response: 0.25<br>Prediction: 0.232<br>education-num = 9.0<br>decreases average response <br>by 0.032", "Average response: 0.25<br>Prediction: 0.232<br>hours-per-week = 40.0<br>increases average response <br>by 0.018", "Average response: 0.25<br>Prediction: 0.232<br>age = 35.0<br>increases average response <br>by 0.016", "Average response: 0.25<br>Prediction: 0.232<br>marital-status = 2.0<br>increases average response <br>by 0.009", "Average response: 0.25<br>Prediction: 0.232<br>capital-loss = 0.0<br>decreases average response <br>by 0.007", "Average response: 0.25<br>Prediction: 0.232<br>workclass = 2.0<br>increases average response <br>by 0.006", "Average response: 0.25<br>Prediction: 0.232<br>+ all other factors<br>increases average response <br>by 0.016"], "marker": {"color": ["#f05a71", "#8bdcbe", "#f05a71", "#f05a71", "#8bdcbe", "#8bdcbe", "#8bdcbe", "#f05a71", "#8bdcbe", "#8bdcbe"]}, "orientation": "h", "showlegend": false, "text": ["-0.068", "+0.054", "-0.033", "-0.032", "+0.018", "+0.016", "+0.009", "-0.007", "+0.006", "+0.016"], "textposition": "outside", "type": "bar", "x": [-0.068, 0.054, -0.033, -0.032, 0.018, 0.016, 0.009, -0.007, 0.006, 0.016], "xaxis": "x", "y": ["relationship = 4.0", "occupation = 1.0", "capital-gain = 0.0", "education-num = 9.0", "hours-per-week = 40.0", "age = 35.0", "marital-status = 2.0", "capital-loss = 0.0", "workclass = 2.0", "+ all other factors"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 373.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.25041741132736206, "x1": 0.25041741132736206, "xref": "x", "y0": -1, "y1": 11, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Shapley Values", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [0, 1], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('b62263cf-fcec-4fa9-8e13-cdfb8db570b3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
import matplotlib
from matplotlib.pyplot import figure
figure(num=None, figsize=(3.5, 7), dpi=100)
exp.predict_parts(test_set.iloc[2, :], type='break_down').plot(min_max=[0,1])
# Out:
# <div>                            <div id="6b493440-7adc-4404-b600-c42118a04e44" class="plotly-graph-div" style="height:413.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b493440-7adc-4404-b600-c42118a04e44")) {                    Plotly.newPlot(                        "6b493440-7adc-4404-b600-c42118a04e44",                        [{"base": 0.25041741132736206, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 0.25<br>Prediction: 0.232", "occupation = 1.0<br>increases average response by", "workclass = 2.0<br>increases average response by", "race = 1.0<br>increases average response by", "native-country = 41.0<br>increases average response by", "capital-loss = 0.0<br>decreases average response by", "marital-status = 2.0<br>decreases average response by", "sex = 1.0<br>decreases average response by", "hours-per-week = 40.0<br>decreases average response by", "capital-gain = 0.0<br>decreases average response by", "age = 35.0<br>decreases average response by", "+ all other factors<br>decreases average response by", "Average response: 0.25<br>Prediction: 0.232"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["0.25", "+0.029", "+0.008", "+0.004", "+0.001", "-0.005", "-0.017", "-0.007", "-0.015", "-0.021", "-0.007", "-0.049", "0.232"], "textposition": "outside", "totals": {"marker": {"color": "#371ea3"}}, "type": "waterfall", "x": [0.0, 0.028999999165534973, 0.00800000037997961, 0.004000000189989805, 0.0010000000474974513, -0.004999999888241291, -0.017000000923871994, -0.007000000216066837, -0.014999999664723873, -0.020999999716877937, -0.007000000216066837, -0.04899999871850014, -0.017999999225139618], "xaxis": "x", "y": ["intercept", "occupation = 1.0", "workclass = 2.0", "race = 1.0", "native-country = 41.0", "capital-loss = 0.0", "marital-status = 2.0", "sex = 1.0", "hours-per-week = 40.0", "capital-gain = 0.0", "age = 35.0", "+ all other factors", "prediction"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 413.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.25041741132736206, "x1": 0.25041741132736206, "xref": "x", "y0": -1, "y1": 13, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Break Down", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [0, 1], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompa ...
#
# var gd = document.getElementById('6b493440-7adc-4404-b600-c42118a04e44');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
exp.predict_parts(test_set.iloc[9, :], type='shap').plot(min_max=[0,1])
# Out:
# <div>                            <div id="b105ffcf-39e0-4565-8f43-fa6d1d86e38e" class="plotly-graph-div" style="height:373.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b105ffcf-39e0-4565-8f43-fa6d1d86e38e")) {                    Plotly.newPlot(                        "b105ffcf-39e0-4565-8f43-fa6d1d86e38e",                        [{"base": 0.25041741132736206, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 0.25<br>Prediction: 0.0<br>age = 19.0<br>decreases average response <br>by 0.074", "Average response: 0.25<br>Prediction: 0.0<br>relationship = 3.0<br>decreases average response <br>by 0.049", "Average response: 0.25<br>Prediction: 0.0<br>hours-per-week = 20.0<br>decreases average response <br>by 0.045", "Average response: 0.25<br>Prediction: 0.0<br>capital-gain = 0.0<br>decreases average response <br>by 0.03", "Average response: 0.25<br>Prediction: 0.0<br>marital-status = 7.0<br>decreases average response <br>by 0.029", "Average response: 0.25<br>Prediction: 0.0<br>fnlwgt = 277000.0<br>decreases average response <br>by 0.01", "Average response: 0.25<br>Prediction: 0.0<br>education-num = 10.0<br>decreases average response <br>by 0.006", "Average response: 0.25<br>Prediction: 0.0<br>workclass = 4.0<br>decreases average response <br>by 0.005", "Average response: 0.25<br>Prediction: 0.0<br>capital-loss = 0.0<br>decreases average response <br>by 0.004", "Average response: 0.25<br>Prediction: 0.0<br>+ all other factors<br>increases average response <br>by 0.002"], "marker": {"color": ["#f05a71", "#f05a71", "#f05a71", "#f05a71", "#f05a71", "#f05a71", "#f05a71", "#f05a71", "#f05a71", "#8bdcbe"]}, "orientation": "h", "showlegend": false, "text": ["-0.074", "-0.049", "-0.045", "-0.03", "-0.029", "-0.01", "-0.006", "-0.005", "-0.004", "+0.002"], "textposition": "outside", "type": "bar", "x": [-0.074, -0.049, -0.045, -0.03, -0.029, -0.01, -0.006, -0.005, -0.004, 0.002], "xaxis": "x", "y": ["age = 19.0", "relationship = 3.0", "hours-per-week = 20.0", "capital-gain = 0.0", "marital-status = 7.0", "fnlwgt = 277000.0", "education-num = 10.0", "workclass = 4.0", "capital-loss = 0.0", "+ all other factors"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 373.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.25041741132736206, "x1": 0.25041741132736206, "xref": "x", "y0": -1, "y1": 11, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Shapley Values", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [0, 1], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('b105ffcf-39e0-4565-8f43-fa6d1d86e38e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
exp.predict_parts(test_set.iloc[9, :], type='break_down').plot(min_max=[0,1])
# Out:
# <div>                            <div id="dbfbc7e2-2c3b-4b46-bc51-12531a654a41" class="plotly-graph-div" style="height:413.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbfbc7e2-2c3b-4b46-bc51-12531a654a41")) {                    Plotly.newPlot(                        "dbfbc7e2-2c3b-4b46-bc51-12531a654a41",                        [{"base": 0.25041741132736206, "connector": {"line": {"color": "#371ea3", "dash": "solid", "width": 1}, "mode": "spanning"}, "decreasing": {"marker": {"color": "#f05a71"}}, "hoverinfo": "text+delta", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Average response: 0.25<br>Prediction: 0.0", "occupation = 3.0<br>increases average response by", "race = 1.0<br>increases average response by", "native-country = 41.0<br>decreases average response by", "workclass = 4.0<br>decreases average response by", "capital-loss = 0.0<br>decreases average response by", "sex = 1.0<br>decreases average response by", "capital-gain = 0.0<br>decreases average response by", "education-num = 10.0<br>increases average response by", "marital-status = 7.0<br>decreases average response by", "fnlwgt = 277000.0<br>increases average response by", "+ all other factors<br>decreases average response by", "Average response: 0.25<br>Prediction: 0.0"], "increasing": {"marker": {"color": "#8bdcbe"}}, "measure": ["relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "total"], "orientation": "h", "showlegend": false, "text": ["0.25", "+0.012", "+0.003", "0.0", "-0.032", "-0.009", "-0.002", "-0.024", "+0.009", "-0.077", "+0.001", "-0.128", "0.0"], "textposition": "outside", "totals": {"marker": {"color": "#371ea3"}}, "type": "waterfall", "x": [0.0, 0.012000000104308128, 0.003000000026077032, 0.0, -0.03200000151991844, -0.008999999612569809, -0.0020000000949949026, -0.024000000208616257, 0.008999999612569809, -0.07699999958276749, 0.0010000000474974513, -0.12800000607967377, -0.25], "xaxis": "x", "y": ["intercept", "occupation = 3.0", "race = 1.0", "native-country = 41.0", "workclass = 4.0", "capital-loss = 0.0", "sex = 1.0", "capital-gain = 0.0", "education-num = 10.0", "marital-status = 7.0", "fnlwgt = 277000.0", "+ all other factors", "prediction"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "contribution", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 413.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.25041741132736206, "x1": 0.25041741132736206, "xref": "x", "y0": -1, "y1": 13, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Break Down", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [0, 1], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCart ...
#
# var gd = document.getElementById('dbfbc7e2-2c3b-4b46-bc51-12531a654a41');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ### Dalex also offers a number of plots to visualize the overall behaviour of the black box model

# %%
exp.model_parts().plot()
# Out:
# <div>                            <div id="a09ba041-f420-4aca-815f-2310f02681d9" class="plotly-graph-div" style="height:383.0px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a09ba041-f420-4aca-815f-2310f02681d9")) {                    Plotly.newPlot(                        "a09ba041-f420-4aca-815f-2310f02681d9",                        [{"base": 0.0, "hoverinfo": "text", "hoverlabel": {"bgcolor": "rgba(0,0,0,0.8)"}, "hovertext": ["Model: XGBClassifier loss after<br>variable: age is permuted: 0.054<br>Drop-out loss change: +0.054", "Model: XGBClassifier loss after<br>variable: capital-gain is permuted: 0.05<br>Drop-out loss change: +0.05", "Model: XGBClassifier loss after<br>variable: relationship is permuted: 0.045<br>Drop-out loss change: +0.045", "Model: XGBClassifier loss after<br>variable: fnlwgt is permuted: 0.044<br>Drop-out loss change: +0.044", "Model: XGBClassifier loss after<br>variable: education-num is permuted: 0.04<br>Drop-out loss change: +0.04", "Model: XGBClassifier loss after<br>variable: hours-per-week is permuted: 0.025<br>Drop-out loss change: +0.025", "Model: XGBClassifier loss after<br>variable: occupation is permuted: 0.013<br>Drop-out loss change: +0.013", "Model: XGBClassifier loss after<br>variable: capital-loss is permuted: 0.01<br>Drop-out loss change: +0.01", "Model: XGBClassifier loss after<br>variable: marital-status is permuted: 0.001<br>Drop-out loss change: +0.001", "Model: XGBClassifier loss after<br>variable: workclass is permuted: 0.001<br>Drop-out loss change: +0.001"], "marker": {"color": "#46bac2"}, "orientation": "h", "showlegend": false, "text": ["+0.054", "+0.05", "+0.045", "+0.044", "+0.04", "+0.025", "+0.013", "+0.01", "+0.001", "+0.001"], "textposition": "outside", "type": "bar", "x": [0.05389587444482495, 0.049886110975205344, 0.0454550396573, 0.04426015623725882, 0.03977635348543899, 0.02478757930100949, 0.012664242107952606, 0.010176623122461892, 0.001137803001886295, 0.0009198101668378533], "xaxis": "x", "y": ["age", "capital-gain", "relationship", "fnlwgt", "education-num", "hours-per-week", "occupation", "capital-loss", "marital-status", "workclass"], "yaxis": "y"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "XGBClassifier", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "drop-out loss", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}], "font": {"color": "#371ea3"}, "height": 383.0, "margin": {"b": 71, "r": 30, "t": 78}, "shapes": [{"line": {"color": "#371ea3", "dash": "dot", "width": 1.5}, "type": "line", "x0": 0.0, "x1": 0.0, "xref": "x", "y0": -1, "y1": 10, "yref": "y"}], "template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Variable Importance", "x": 0.15}, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "range": [-0.008084381166723742, 0.06198025561154869], "tickcolor": "white", "ticklen": 3, "ticks": "outside", "type": "linear", "zeroline": false}, "yaxis": {"anchor": "x", "automargin": true, "autorange": "reversed", "domain": [0.0, 1.0], "fixedrange": true, "gridwidth": 2, "tickcolor": "white", "ticklen": 10, "ticks": "outside", "type": "category"}},                        {"displaylogo": false, "staticPlot": false, "toImageButtonOptions": {"height": null, "width": null}, "modeBarButtonsToRemove": ["sendDataToCloud", "lasso2d", "autoScale2d", "select2d", "zoom2d", "pan2d", "zoomIn2d", "zoomOut2d", "resetScale2d", "toggleSpikelines", "hoverCompareCartesian", "hoverClosestCartesian"], "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('a09ba041-f420-4aca-815f-2310f02681d9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
exp.model_performance('classification').plot()
# Out:
# <div>                            <div id="4e8ff378-2613-4064-918f-573f98ea9b29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e8ff378-2613-4064-918f-573f98ea9b29")) {                    Plotly.newPlot(                        "4e8ff378-2613-4064-918f-573f98ea9b29",                        [{"line": {"shape": "hv"}, "marker": {"color": "#46bac2"}, "name": "XGBClassifier", "type": "scatter", "x": [1.0238312597721233e-06, 1.0521355306991609e-06, 1.0712470839280286e-06, 1.0798364655784098e-06, 1.1471930747575243e-06, 1.1746265045076143e-06, 1.2668247109104414e-06, 1.2695265922957333e-06, 1.26972884118004e-06, 1.273190719075501e-06, 1.3149910955689847e-06, 1.3361807305045659e-06, 1.3641961231769528e-06, 1.3987423699290957e-06, 1.4432559964916436e-06, 1.4550250853062607e-06, 1.530517579340085e-06, 1.5322583521992783e-06, 1.5492632883251645e-06, 1.5844519793972722e-06, 1.5888036841715802e-06, 1.594722448317043e-06, 1.605130023563106e-06, 1.628119889574009e-06, 1.6454807791888015e-06, 1.6639407931506867e-06, 1.6700788592061144e-06, 1.6789305163911195e-06, 1.6924198007473024e-06, 1.7275369827984832e-06, 1.7389686490787426e-06, 1.7671706018518307e-06, 1.7946571233551367e-06, 1.801473331397574e-06, 1.8042397869066917e-06, 1.813916696846718e-06, 1.8472568399374723e-06, 1.891093802441901e-06, 1.9396836705709575e-06, 1.942864400916733e-06, 1.9609690298239e-06, 1.9613262338680215e-06, 2.0132295048824744e-06, 2.0156769551249454e-06, 2.036741079791682e-06, 2.0422417037480045e-06, 2.0560539724101545e-06, 2.0718300675071077e-06, 2.101434347423492e-06, 2.1084501895529684e-06, 2.11521728488151e-06, 2.123344074789202e-06, 2.1341136289265705e-06, 2.1437172108562663e-06, 2.170608922824613e-06, 2.180936007789569e-06, 2.1816329081048025e-06, 2.1847206426173216e-06, 2.1908297185291303e-06, 2.1939240468782373e-06, 2.213760126323905e-06, 2.2200415514816996e-06, 2.2501062630908564e-06, 2.2605529466090957e-06, 2.2799756607128074e-06, 2.289412350364728e-06, 2.2961446575209266e-06, 2.3101799797586864e-06, 2.3273755687114317e-06, 2.345240091017331e-06, 2.3726654490019428e-06, 2.386647111052298e-06, 2.3898562631075038e-06, 2.4193925582949305e-06, 2.4269145342259435e-06, 2.457002665323671e-06, 2.473427002769313e-06, 2.4893765839806292e-06, 2.489761300239479e-06, 2.5024205569934566e-06, 2.5050371732504573e-06, 2.516454060241813e-06, 2.5192177872668253e-06, 2.52489894592145e-06, 2.529268158468767e-06, 2.5345948415633757e-06, 2.555341325205518e-06, 2.561895371400169e-06, 2.5700783226056956e-06, 2.5732620088092517e-06, 2.5775354970392073e-06, 2.589675204944797e-06, 2.594362058516708e-06, 2.595010300865397e-06, 2.595586920506321e-06, 2.6232364689349197e-06, 2.6301529487682274e-06, 2.641731498442823e-06, 2.6497552880755393e-06, 2.658657649590168e-06, 2.6682719180826098e-06, 2.7068449526268523e-06, 2.719111307669664e-06, 2.724871819737018e-06, 2.7392122774472227e-06, 2.7636647246254142e-06, 2.767008709270158e-06, 2.79277992376592e-06, 2.7942933229496703e-06, 2.794565034491825e-06, 2.8008269055135315e-06, 2.8465210561989807e-06, 2.8649230898736278e-06, 2.885182766476646e-06, 2.8939016374351922e-06, 2.899274477385916e-06, 2.9048983378743287e-06, 2.911804813265917e-06, 2.9214256755949464e-06, 2.9513498702726793e-06, 2.9519076178985415e-06, 2.9602267659356585e-06, 2.9608986551465932e-06, 2.9803240977344103e-06, 2.9874727260903455e-06, 2.991738028867985e-06, 3.0015144147910178e-06, 3.0239161787903868e-06, 3.0245448670029873e-06, 3.0359133234014735e-06, 3.0386013349925634e-06, 3.041570380446501e-06, 3.0593625979236094e-06, 3.1008203222882003e-06, 3.110001216555247e-06, 3.1212296107696602e-06, 3.1444108117284486e-06, 3.1446686534764012e-06, 3.155378180963453e-06, 3.1646452498534927e-06, 3.164663439747528e-06, 3.1685196972830454e-06, 3.20140 ...
